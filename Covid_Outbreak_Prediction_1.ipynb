# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('C:/Users/Arunima/Downloads/covid_1.csv')

# %%
data
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 0          ABW          Aruba  2020-03-13            2          2
# 1          ABW          Aruba  2020-03-20            4          2
# 2          ABW          Aruba  2020-03-24           12          8
# 3          ABW          Aruba  2020-03-25           17          5
# 4          ABW          Aruba  2020-03-26           19          2
# ...        ...            ...         ...          ...        ...
# 19491      NaN  International  2020-02-28          705          0
# 19492      NaN  International  2020-02-29          705          0
# 19493      NaN  International  2020-03-01          705          0
# 19494      NaN  International  2020-03-02          705          0
# 19495      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 0                 0           0                   18.733
# ...

# %%
data.isna()
# Out:
#        iso_code  location   date  total_cases  new_cases  total_deaths  \
# 0         False     False  False        False      False         False
# 1         False     False  False        False      False         False
# 2         False     False  False        False      False         False
# 3         False     False  False        False      False         False
# 4         False     False  False        False      False         False
# ...         ...       ...    ...          ...        ...           ...
# 19491      True     False  False        False      False         False
# 19492      True     False  False        False      False         False
# 19493      True     False  False        False      False         False
# 19494      True     False  False        False      False         False
# 19495      True     False  False        False      False         False
#
#        new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19496 entries, 0 to 19495
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         19432 non-null  object
#  1   location                         19496 non-null  object
#  2   date                             19496 non-null  object
#  3   total_cases                      19496 non-null  int64
#  4   new_cases                        19496 non-null  int64
#  5   total_deaths                     19496 non-null  int64
#  6   new_deaths                       19496 non-null  int64
#  7   total_cases_per_million          19119 non-null  float64
#  8   new_cases_per_million            19119 non-null  float64
#  9   total_deaths_per_million         19119 non-null  float64
#  10  new_deaths_per_million           19119 non-null  float64
#  11  total_tests                      5164 non-null   float64
# ...

# %%
data
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 0          ABW          Aruba  2020-03-13            2          2
# 1          ABW          Aruba  2020-03-20            4          2
# 2          ABW          Aruba  2020-03-24           12          8
# 3          ABW          Aruba  2020-03-25           17          5
# 4          ABW          Aruba  2020-03-26           19          2
# ...        ...            ...         ...          ...        ...
# 19491      NaN  International  2020-02-28          705          0
# 19492      NaN  International  2020-02-29          705          0
# 19493      NaN  International  2020-03-01          705          0
# 19494      NaN  International  2020-03-02          705          0
# 19495      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 0                 0           0                   18.733
# ...

# %%
data.head(5)
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 0                       0.0  ...         13.085          7.452
# ...

# %%
data
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 0          ABW          Aruba  2020-03-13            2          2
# 1          ABW          Aruba  2020-03-20            4          2
# 2          ABW          Aruba  2020-03-24           12          8
# 3          ABW          Aruba  2020-03-25           17          5
# 4          ABW          Aruba  2020-03-26           19          2
# ...        ...            ...         ...          ...        ...
# 19491      NaN  International  2020-02-28          705          0
# 19492      NaN  International  2020-02-29          705          0
# 19493      NaN  International  2020-03-01          705          0
# 19494      NaN  International  2020-03-02          705          0
# 19495      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 0                 0           0                   18.733
# ...

# %%
data['total_deaths'] = data['total_deaths'].replace(0, np.nan)

# %%
data['new_deaths'] = data['new_deaths'].replace(0, np.nan)

# %%
data
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 0          ABW          Aruba  2020-03-13            2          2
# 1          ABW          Aruba  2020-03-20            4          2
# 2          ABW          Aruba  2020-03-24           12          8
# 3          ABW          Aruba  2020-03-25           17          5
# 4          ABW          Aruba  2020-03-26           19          2
# ...        ...            ...         ...          ...        ...
# 19491      NaN  International  2020-02-28          705          0
# 19492      NaN  International  2020-02-29          705          0
# 19493      NaN  International  2020-03-01          705          0
# 19494      NaN  International  2020-03-02          705          0
# 19495      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 0               NaN         NaN                   18.733
# ...

# %%
new_data = data.dropna(axis=0, how= 'any')

# %%
new_data
# Out:
#       iso_code      location        date  total_cases  new_cases  \
# 1737       BGD    Bangladesh  2020-03-22           24          7
# 1738       BGD    Bangladesh  2020-03-23           27          3
# 1740       BGD    Bangladesh  2020-03-25           39          6
# 1741       BGD    Bangladesh  2020-03-26           39          0
# 1748       BGD    Bangladesh  2020-04-02           54          3
# ...        ...           ...         ...          ...        ...
# 19143      ZAF  South Africa  2020-05-14        12074        724
# 19144      ZAF  South Africa  2020-05-15        12739        665
# 19145      ZAF  South Africa  2020-05-16        13524        785
# 19146      ZAF  South Africa  2020-05-17        14355        831
# 19147      ZAF  South Africa  2020-05-18        15515       1160
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 1737            2.0         2.0                    0.146
# 1738            3.0         1.0                    0.164
# ...

# %%
new_data.drop('female_smokers', axis =1 )
# Out:
#       iso_code      location        date  total_cases  new_cases  \
# 1737       BGD    Bangladesh  2020-03-22           24          7
# 1738       BGD    Bangladesh  2020-03-23           27          3
# 1740       BGD    Bangladesh  2020-03-25           39          6
# 1741       BGD    Bangladesh  2020-03-26           39          0
# 1748       BGD    Bangladesh  2020-04-02           54          3
# ...        ...           ...         ...          ...        ...
# 19143      ZAF  South Africa  2020-05-14        12074        724
# 19144      ZAF  South Africa  2020-05-15        12739        665
# 19145      ZAF  South Africa  2020-05-16        13524        785
# 19146      ZAF  South Africa  2020-05-17        14355        831
# 19147      ZAF  South Africa  2020-05-18        15515       1160
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 1737            2.0         2.0                    0.146
# 1738            3.0         1.0                    0.164
# ...

# %%
new_data
# Out:
#       iso_code      location        date  total_cases  new_cases  \
# 1737       BGD    Bangladesh  2020-03-22           24          7
# 1738       BGD    Bangladesh  2020-03-23           27          3
# 1740       BGD    Bangladesh  2020-03-25           39          6
# 1741       BGD    Bangladesh  2020-03-26           39          0
# 1748       BGD    Bangladesh  2020-04-02           54          3
# ...        ...           ...         ...          ...        ...
# 19143      ZAF  South Africa  2020-05-14        12074        724
# 19144      ZAF  South Africa  2020-05-15        12739        665
# 19145      ZAF  South Africa  2020-05-16        13524        785
# 19146      ZAF  South Africa  2020-05-17        14355        831
# 19147      ZAF  South Africa  2020-05-18        15515       1160
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 1737            2.0         2.0                    0.146
# 1738            3.0         1.0                    0.164
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 461 entries, 1737 to 19147
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         461 non-null    object
#  1   location                         461 non-null    object
#  2   date                             461 non-null    object
#  3   total_cases                      461 non-null    int64
#  4   new_cases                        461 non-null    int64
#  5   total_deaths                     461 non-null    float64
#  6   new_deaths                       461 non-null    float64
#  7   total_cases_per_million          461 non-null    float64
#  8   new_cases_per_million            461 non-null    float64
#  9   total_deaths_per_million         461 non-null    float64
#  10  new_deaths_per_million           461 non-null    float64
#  11  total_tests                      461 non-null    float64
# ...

# %%
new_data.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
new_data.rename(columns={'iso_code':'ISO'})
# Out:
#        ISO      location        date  total_cases  new_cases  total_deaths  \
# 1737   BGD    Bangladesh  2020-03-22           24          7           2.0
# 1738   BGD    Bangladesh  2020-03-23           27          3           3.0
# 1740   BGD    Bangladesh  2020-03-25           39          6           4.0
# 1741   BGD    Bangladesh  2020-03-26           39          0           5.0
# 1748   BGD    Bangladesh  2020-04-02           54          3           6.0
# ...    ...           ...         ...          ...        ...           ...
# 19143  ZAF  South Africa  2020-05-14        12074        724         219.0
# 19144  ZAF  South Africa  2020-05-15        12739        665         238.0
# 19145  ZAF  South Africa  2020-05-16        13524        785         247.0
# 19146  ZAF  South Africa  2020-05-17        14355        831         261.0
# 19147  ZAF  South Africa  2020-05-18        15515       1160         264.0
#
#        new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
new_data.rename(columns={'total_cases': 'TotalCases', 'new_cases': 'New_Cases','new_cases_per_million': 'New_Cases_Per_Million'})
# Out:
#       iso_code      location        date  TotalCases  New_Cases  total_deaths  \
# 1737       BGD    Bangladesh  2020-03-22          24          7           2.0
# 1738       BGD    Bangladesh  2020-03-23          27          3           3.0
# 1740       BGD    Bangladesh  2020-03-25          39          6           4.0
# 1741       BGD    Bangladesh  2020-03-26          39          0           5.0
# 1748       BGD    Bangladesh  2020-04-02          54          3           6.0
# ...        ...           ...         ...         ...        ...           ...
# 19143      ZAF  South Africa  2020-05-14       12074        724         219.0
# 19144      ZAF  South Africa  2020-05-15       12739        665         238.0
# 19145      ZAF  South Africa  2020-05-16       13524        785         247.0
# 19146      ZAF  South Africa  2020-05-17       14355        831         261.0
# 19147      ZAF  South Africa  2020-05-18       15515       1160         264.0
#
# ...

# %%
new_data['location'].value_counts()
# Out:
# location
# Mexico          60
# Pakistan        55
# Indonesia       53
# Colombia        52
# India           50
# Bangladesh      47
# South Africa    40
# Tunisia         24
# Kazakhstan      21
# Kenya           20
# El Salvador     17
# Paraguay         9
# Costa Rica       8
# Myanmar          3
# Ethiopia         1
# Ghana            1
# Name: count, dtype: int64

# %%
new_data['location'].value_counts()
# Out:
# location
# Mexico          60
# Pakistan        55
# Indonesia       53
# Colombia        52
# India           50
# Bangladesh      47
# South Africa    40
# Tunisia         24
# Kazakhstan      21
# Kenya           20
# El Salvador     17
# Paraguay         9
# Costa Rica       8
# Myanmar          3
# Ethiopia         1
# Ghana            1
# Name: count, dtype: int64

# %%
print(new_data[new_data.location !=0])
# Out:
#       iso_code      location        date  total_cases  new_cases  \
# 1737       BGD    Bangladesh  2020-03-22           24          7
# 1738       BGD    Bangladesh  2020-03-23           27          3
# 1740       BGD    Bangladesh  2020-03-25           39          6
# 1741       BGD    Bangladesh  2020-03-26           39          0
# 1748       BGD    Bangladesh  2020-04-02           54          3
# ...        ...           ...         ...          ...        ...
# 19143      ZAF  South Africa  2020-05-14        12074        724
# 19144      ZAF  South Africa  2020-05-15        12739        665
# 19145      ZAF  South Africa  2020-05-16        13524        785
# 19146      ZAF  South Africa  2020-05-17        14355        831
# 19147      ZAF  South Africa  2020-05-18        15515       1160
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 1737            2.0         2.0                    0.146
# 1738            3.0         1.0                    0.164
# ...

# %%
list1 = ['Ghana']

# %%
print(new_data[new_data.location.isin(list1) == False])
# Out:
#       iso_code      location        date  total_cases  new_cases  \
# 1737       BGD    Bangladesh  2020-03-22           24          7
# 1738       BGD    Bangladesh  2020-03-23           27          3
# 1740       BGD    Bangladesh  2020-03-25           39          6
# 1741       BGD    Bangladesh  2020-03-26           39          0
# 1748       BGD    Bangladesh  2020-04-02           54          3
# ...        ...           ...         ...          ...        ...
# 19143      ZAF  South Africa  2020-05-14        12074        724
# 19144      ZAF  South Africa  2020-05-15        12739        665
# 19145      ZAF  South Africa  2020-05-16        13524        785
# 19146      ZAF  South Africa  2020-05-17        14355        831
# 19147      ZAF  South Africa  2020-05-18        15515       1160
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 1737            2.0         2.0                    0.146
# 1738            3.0         1.0                    0.164
# ...

# %%
new_data['location'].value_counts()
# Out:
# location
# Mexico          60
# Pakistan        55
# Indonesia       53
# Colombia        52
# India           50
# Bangladesh      47
# South Africa    40
# Tunisia         24
# Kazakhstan      21
# Kenya           20
# El Salvador     17
# Paraguay         9
# Costa Rica       8
# Myanmar          3
# Ethiopia         1
# Ghana            1
# Name: count, dtype: int64

# %%
new_data.loc[:, new_data.columns != 'location']
# Out:
#       iso_code        date  total_cases  new_cases  total_deaths  new_deaths  \
# 1737       BGD  2020-03-22           24          7           2.0         2.0
# 1738       BGD  2020-03-23           27          3           3.0         1.0
# 1740       BGD  2020-03-25           39          6           4.0         1.0
# 1741       BGD  2020-03-26           39          0           5.0         1.0
# 1748       BGD  2020-04-02           54          3           6.0         1.0
# ...        ...         ...          ...        ...           ...         ...
# 19143      ZAF  2020-05-14        12074        724         219.0        13.0
# 19144      ZAF  2020-05-15        12739        665         238.0        19.0
# 19145      ZAF  2020-05-16        13524        785         247.0         9.0
# 19146      ZAF  2020-05-17        14355        831         261.0        14.0
# 19147      ZAF  2020-05-18        15515       1160         264.0         3.0
#
# ...

# %%
new_data.describe()
# Out:
#          total_cases    new_cases  total_deaths  new_deaths  \
# count     461.000000   461.000000    461.000000  461.000000
# mean    11110.594360   626.950108    511.342733   28.895879
# std     18668.462123   978.506293    982.253722   56.708503
# min        18.000000     0.000000      1.000000    1.000000
# 25%       889.000000    73.000000     21.000000    2.000000
# 50%      4241.000000   275.000000    131.000000    9.000000
# 75%     12272.000000   688.000000    496.000000   26.000000
# max    125101.000000  6654.000000   6510.000000  424.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count               461.000000             461.000000
# mean                 70.017486               3.861657
# std                  80.360058               4.220683
# min                   0.138000               0.000000
# 25%                  14.097000               1.005000
# 50%                  42.254000               2.341000
# ...

# %%
new_data.describe(include='O')
# Out:
#        iso_code location        date     tests_units
# count       461      461         461             461
# unique       16       16          66               4
# top         MEX   Mexico  2020-04-16  samples tested
# freq         60       60          11             161

# %%
new_data['location'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Arunima\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 new_data['location'].value_counts()
#
# ...

# %%
new_data.isna().any()
# Out:
# iso_code                           False
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million            False
# new_cases_per_million              False
# total_deaths_per_million           False
# new_deaths_per_million             False
# total_tests                        False
# new_tests                          False
# total_tests_per_thousand           False
# new_tests_per_thousand             False
# new_tests_smoothed                 False
# new_tests_smoothed_per_thousand    False
# tests_units                        False
# stringency_index                   False
# population                         False
# population_density                 False
# median_age                         False
# aged_65_older                      False
# ...

# %%
indian_cases = new_data[new_data['location']== 'India']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Arunima\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 indian_cases = new_data[new_data['location']== 'India']
#
# ...

# %%
indian_cases.head(5)
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8458      IND    India  2020-03-20          191         26           4.0
# 8461      IND    India  2020-03-23          439        119           7.0
# 8462      IND    India  2020-03-24          492         53           9.0
# 8472      IND    India  2020-04-03         2301        336          56.0
# 8473      IND    India  2020-04-04         2902        601          68.0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8458         1.0                    0.138                  0.019
# 8461         3.0                    0.318                  0.086
# 8462         2.0                    0.357                  0.038
# 8472         6.0                    1.667                  0.243
# 8473        12.0                    2.103                  0.436
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
df = new_data

# %%
df
# Out:
# 1737       Bangladesh
# 1738       Bangladesh
# 1740       Bangladesh
# 1741       Bangladesh
# 1748       Bangladesh
#              ...
# 19143    South Africa
# 19144    South Africa
# 19145    South Africa
# 19146    South Africa
# 19147    South Africa
# Name: location, Length: 461, dtype: object

# %%
Ghana_cases
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 6869      GHA    Ghana  2020-05-14         5408        281          24.0
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 6869         2.0                  174.042                  9.043
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# 6869                     0.772  ...          3.385          1.948
#
#       gdp_per_capita  extreme_poverty  cvd_death_rate  diabetes_prevalence  \
# 6869         4227.63             12.0         298.245                 4.97
#
#       female_smokers male_smokers  handwashing_facilities  \
# 6869             0.3          7.7                  41.047
#
#       hospital_beds_per_100k
# 6869                     0.9
#
# [1 rows x 32 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.lineplot(x ='date',y='total_cases',data=indian_cases)
# Out:
# <Axes: xlabel='date', ylabel='total_cases'>

# %%
india_last_five_years = indian_cases.tail()

# %%
sns.lineplot(x ='date', y = 'total_cases', data = india_last_five_years)
# Out:
# <Axes: xlabel='date', ylabel='total_cases'>

# %%
sns.lineplot(x = 'date', y ="total_tests",data = india_last_five_years)
# Out:
# <Axes: xlabel='date', ylabel='total_tests'>

# %%
# Out:
# Empty DataFrame
# Columns: [iso_code, location, date, total_cases, new_cases, total_deaths, new_deaths, total_cases_per_million, new_cases_per_million, total_deaths_per_million, new_deaths_per_million, total_tests, new_tests, total_tests_per_thousand, new_tests_per_thousand, new_tests_smoothed, new_tests_smoothed_per_thousand, tests_units, stringency_index, population, population_density, median_age, aged_65_older, aged_70_older, gdp_per_capita, extreme_poverty, cvd_death_rate, diabetes_prevalence, female_smokers, male_smokers, handwashing_facilities, hospital_beds_per_100k]
# Index: []
#
# [0 rows x 32 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Arunima\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'location'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 new_data['location'].value_counts()
#
# ...

# %%
# Out:
# 1737       Bangladesh
# 1738       Bangladesh
# 1740       Bangladesh
# 1741       Bangladesh
# 1748       Bangladesh
#              ...
# 19143    South Africa
# 19144    South Africa
# 19145    South Africa
# 19146    South Africa
# 19147    South Africa
# Name: location, Length: 461, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Arunima\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'location1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 indian_cases = new_data[new_data['location1']== 'India']
#
# ...
