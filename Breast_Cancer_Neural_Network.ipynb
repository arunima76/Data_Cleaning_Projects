# %%
import pandas as pd
import numpy as np
import os
from glob import glob
import random
import matplotlib.pylab as plt
from sklearn.model_selection import train_test_split
import keras
from keras.utils.np_utils import to_categorical
from keras.model import Sequential
from keras.optimizer import Adam, Adagard, Adadelta, SGD,RMSprop
from keras.layers import Dense, Dropout,Activation,Conv2D
from keras.layers import Flatten,MaxPool2D,MaxPooling2D, BatchNormalization
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6300/813728276.py in <module>
#       6 import matplotlib.pylab as plt
#       7 from sklearn.model_selection import train_test_split
# ----> 8 import keras
#       9 from keras.utils.np_utils import to_categorical
#      10 from keras.model import Sequential
#
# ModuleNotFoundError: No module named 'keras'

# %%
# Out:
#   File "C:\Users\Arunima\AppData\Local\Temp/ipykernel_6300/2136062895.py", line 1
#     df = pd.read_csv(""
#                        ^
# SyntaxError: unexpected EOF while parsing

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.  Downloading tensorflow_intel-2.13.0-cp39-cp39-win_amd64.whl (276.5 MB)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\Arunima\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\Arunima\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\Arunima\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\Arunima\anaconda3\lib\http\client.py", line 462, in read
#     n = self.readinto(b)
#   File "C:\Users\Arunima\anaconda3\lib\http\client.py", line 506, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\Arunima\anaconda3\lib\socket.py", line 704, in readinto
#     return self._sock.recv_into(b)
# ...

# %%
import tensorflow as tf

# %%
data = pd.read_csv('C:/Users/Arunima/Downloads/data.csv')

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
from IPython.display import Image

# %%
Image(filename='C:/Users/Arunima/Downloads/class0.png')

# %%
from IPython.display import set_matplotlib_formats

set_matplotlib_formats('png', 'pdf')
# Out:
# C:\Users\Arunima\AppData\Local\Temp/ipykernel_6300/327885925.py:3: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('png', 'pdf')

# %%
Image(filename='C:/Users/Arunima/Downloads/class1.png')

# %%
class 0 = []
class 1 = []
